# %%
college = read.csv('../../data/College.csv')
rownames(college) = college[,1]
college = college[,-1]
attach(college)

# %%
pairs(college[1:10])
# Out:
# plot without title

# %%
plot(Private, Outstate, xlab='isPrivate', ylab='Outstate')
# Out:
# plot without title

# %%
Elite = rep("No", nrow(college))
Elite[Top10perc > 50] = "Yes"
Elite = as.factor(Elite)
college=data.frame(college, Elite)

# %%
plot(Elite, Outstate, xlab='isElite', ylab='Outstate')
# Out:
# plot without title

# %%
par(mfrow=c(2,2))
hist(Apps)
hist(Accept)
hist(PhD)
hist(Enroll)
# Out:
# Plot with title "Histogram of Enroll"

# %%
Acceptance = rep(0, nrow(college))
Acceptance = round(Accept / Apps * 100)
college = data.frame(college, Acceptance)

# %%
par(mfrow=c(1,2))
hist(Acceptance)
plot(Elite, Acceptance)
# Out:
# Plot with title "Histogram of Acceptance"

# %% [markdown]
# 8.C.vi) Median acceptance rate for elite universities is slightly above minimum acceptance rate for non-elite universityies (excluding some outliers)
